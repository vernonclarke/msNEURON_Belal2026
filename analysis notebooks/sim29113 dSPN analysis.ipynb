# %%
sim = 'sim29113'

# settings
cell_type='dspn'
model = 3

import os, sys
# compute absolute path of main folder
cwd = os.getcwd()

if os.path.exists(os.path.join(cwd, 'settings.py')):
    main_dir = cwd
else:
    main_dir = os.path.abspath(os.path.join(cwd, '..'))

# set CWD or add to path
os.chdir(main_dir)
sys.path.insert(0, main_dir)

# then import/run settings
# %run -i settings.py

from analysis_functions import *

# Get the current working directory
current_wd = os.getcwd()
# 'sim' + str(sim)

downsample = True

home = os.path.expanduser('~')

# Set working directory
external = False
external_name = 'MacOS10'
target = f'model{model}'

if not external:
    if downsample:
        wd = home + '/Documents/Repositories/msNEURON_Belal2026/downsample/' + cell_type + '/' + target + '/physiological/simulations'
    else:
        wd = home + '/Documents/Repositories/msNEURON_Belal2026/' + cell_type + '/' + target + '/physiological/simulations'
else:
    if downsample:
        wd = '/Volumes/' + external_name + '/Repositories/msNEURON_Belal2026/downsample/' + cell_type + '/' + target + '/physiological/simulations'
    else:
        wd = '/Volumes/' + external_name + '/Repositories/msNEURON_Belal2026/' + cell_type + '/' + target + '/physiological/simulations'


# create path to directory to save analysis
base_path = os.path.join(home, 'Documents', 'Repositories', 'msNEURON_Belal2026', 'analysis')
sim_image_path = os.path.join(base_path, cell_type, sim)
os.makedirs(sim_image_path, exist_ok=True)

save = True

# %%
# Basic plot settings
s = 5 # splprep fits a parametric B-spline to your 2D points 
lwd = 1 # standardise line width

height1 = 600
width1 = 600

height2 = 600
width2 = 800

if cell_type == 'ispn':
    plane='yx'
    mirror=False
    dend_name = 'dend[12]'
    
else:
    plane='xy'
    mirror=False
    dend_name = 'dend[7]'

# %%
# load simulations
sims_dir = os.path.join(wd, sim)
# sim_data = load_data_dicts(sims_dir, verbose=True)

sim_data = load_data_dicts(wd=wd, sim=sim, cell_type=cell_type, verbose=True)

# %%
# check files loaded in correct order
for name in sim_data.keys():
    print(name)

# %%
report_memory(verbose=True)

# %%
# check if coordinates exist
coords_exist = summarise_cell_coordinates(sim_data)

# if so load from v_all_3D else retrieve from cell_build
# this is because the methods to retrieve the cell_coordinates differ so it is important when plotting 3D heatmaps that the correct coordinates are used
# the method to default will only be used when the simulations have no 3d data 
if coords_exist:
    first_sim = next(iter(sim_data.values()))
    v_all_3D = first_sim['v_all_3D']
    first_key = next(iter(v_all_3D)) 
    
    cell_coordinates = np.array(v_all_3D[first_key]['cell_coordinates'], dtype=object)
    _, _, dend_tree = cell_build(cell_type=cell_type, specs=specs, addSpines=True, spine_per_length=spine_per_length, frequency=frequency, d_lambda=d_lambda, verbose=False, dend2remove=None)
else:
    cell, spines, dend_tree = cell_build(cell_type=cell_type, specs=specs, addSpines=True, spine_per_length=spine_per_length, frequency=frequency, d_lambda=d_lambda, verbose=False, dend2remove=None)
    cell_coordinates = []
    
    for sec in cell.somalist:
        h('access ' + sec.name())
        x, y, z, diam = interpolate_3d(sec, 0.5)  # Use 0.5 to refer to the center of the section
        cell_coordinates.append([sec.name(), 0.5, x, y, z, h.distance(0.5, sec=sec), diam])
    
    # Setup for dendritic sections
    for sec in cell.dendlist:
        for seg in sec:
            x, y, z, diam = interpolate_3d(sec, seg.x)
            cell_coordinates.append([sec.name(), seg.x, x, y, z, h.distance(seg.x, sec=sec), diam])
        
    cell_coordinates = np.array(cell_coordinates, dtype=object)

    
fig_morphology = morphology_plot(cell_coordinates, dend_tree, lwd=lwd, s=s, color='grey', height=height1, width=width1, plane=plane, mirror=mirror)

fig_morphology.show(config={"toImageButtonOptions": {"format": "svg"}})
if save:
    fig_morphology.write_image(f"{sim_image_path}/morphology.svg", format='svg', scale=3)

# %%
# Morphology plot with synaptic locations

# extract names and locations of GLUT and GABA inputs from metadata
# using last simulation to get all GABA locations used (fixed)
dend_gaba_all = list(sim_data.values())[-1]['metadata']['dend_gaba']
gaba_locations_all = list(sim_data.values())[-1]['metadata']['gaba_locations']

dend_glut = list(sim_data.values())[-1]['metadata']['dend_glut']
glut_locations = list(sim_data.values())[-1]['metadata']['glutamate_locations']

if len(dend_glut) != len(glut_locations): # one upstate site 
    dend_glut = dend_glut * len(glut_locations)
    
# indices
idxs_gaba = get_coord_index(cell_coordinates=cell_coordinates, target_dendrite=dend_gaba_all, target_location=gaba_locations_all)
idxs_glut = get_coord_index(cell_coordinates=cell_coordinates, target_dendrite=dend_glut, target_location=glut_locations)

# coordinates
coords_gaba = get_coord_index_interp(cell_coordinates=cell_coordinates, target_dendrite=dend_gaba_all, target_location=gaba_locations_all)
coords_glut = get_coord_index_interp(cell_coordinates=cell_coordinates, target_dendrite=dend_glut, target_location=glut_locations)

# with interpolation
fig_morphology = morphology_plot(cell_coordinates=cell_coordinates, dend_tree=dend_tree, idxs=[coords_gaba, coords_glut], 
                                 idxs_colors = ['#7cc57a', '#CD5C5C'], dot_size=[5,6], lwd=lwd, s=s, color='grey', 
                                 height=height1, width=width1, plane=plane, mirror=mirror, alpha=[0.5, 0.25])

fig_path_morphology = morphology_plot(cell_coordinates=cell_coordinates, dend_tree=dend_tree, dend_name=dend_name, idxs=[coords_gaba, coords_glut], 
                                 idxs_colors = ['#7cc57a', '#CD5C5C'], dot_size=[5,6], lwd=lwd, s=s, color='grey', 
                                 height=height1, width=width1, plane=plane, mirror=mirror, alpha=[0.5, 0.25])


fig_morphology.show(config={"toImageButtonOptions": {"format": "svg"}})

fig_path_morphology.show(config={"toImageButtonOptions": {"format": "svg"}})


if save:
    fig_morphology.write_image(f"{sim_image_path}/morphology2.svg", format='svg', scale=3)

# %%
Vsoma2animate_fig = plot3_dt(Vsoma[0:170], yaxis='V (mV)', stim_time = 150, sim_time=sim_time, black_trace=0, gray_trace=1,
                title='somatic voltage', yrange=[-86, 40], xrange=[30, 350], yabline = [-86, -60], 
                width=800, height=400, baseline=100, x_err_bar=25, y_err_bar=20, dt=dt, ds=ds_plot, 
                offset=False, legend=False, alpha=0.6)        

gray_idx_in_fig = len(Vsoma2animate_fig.data)-1 
anim_fig = animate_traces(Vsoma2animate_fig, skip_indices=[0, gray_idx_in_fig], highlighted_trace=1)
anim_fig.show()

# save = True
if save:
    export_html(anim_fig, f"{sim_image_path}/Vsoma_anim.html")
    export_mp4(anim_fig, f"{sim_image_path}/Vsoma_anim.mp4")

# %%
compare_synapse_coords("Glutamatergic", dend_glut, glut_locations, coords_glut)

# %%
compare_synapse_coords("GABAergic", dend_gaba_all, gaba_locations_all, coords_gaba)

# %%
# IMPORTANT #
# ensures order by stim interval while keeping first two

items = list(sim_data.items())

# Keep the first two
first_two = items[:2]

# Sort the rest by timing
rest = items[2:]
rest_sorted = sorted(rest, key=lambda kv: kv[1]['metadata']['timing'])

# Rebuild a new dict with the new order
sim_data = dict(first_two + rest_sorted)

# %%
# Simple output traces
sim_time = next(iter(sim_data.values()))['metadata']['sim_time']

dt = next(iter(sim_data.values()))['metadata']['dt']

if downsample:
    ds_plot = 1
    dt = ds * dt
    
else:
    ds_plot = 10

    
Vsoma = []
Vdend = []

for variables in sim_data.values():
    if 'vsoma' in variables:
        Vsoma.append(variables['vsoma'])
    if 'vdend' in variables:
        Vdend.append(variables['vdend']) 
        
Vsoma_fig = plot3_dt(Vsoma, yaxis='V (mV)', stim_time = 150, sim_time=sim_time, title='somatic voltage', 
                yrange=[-86, 40], yabline = [-86, -60], black_trace=0, gray_trace=1, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=5, dt=dt, ds=ds_plot, offset=False)        

Vdend_fig = plot3_dt(Vdend, yaxis='V (mV)', stim_time = 150, sim_time=sim_time, title='dendritic voltage', 
                yrange=[-86, -10], yabline = [-86, -20], black_trace=0, gray_trace=1, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=5, dt=dt, ds=ds_plot, offset=False)  

Vsoma_fig.show(config={"toImageButtonOptions": {"format": "svg"}})
Vdend_fig.show(config={"toImageButtonOptions": {"format": "svg"}})

if save:
    Vsoma_fig.write_image(f"{sim_image_path}/Vsoma.svg", format='svg', scale=3)
    Vdend_fig.write_image(f"{sim_image_path}/Vdend.svg", format='svg', scale=3)

# %%
timing_range = [v['metadata']['timing'] for v in sim_data.values()]

timing_target_range = [100, 140, 160, 180, 200, 240, 280]
idx = np.where(np.isin(timing_range, timing_target_range))[0]
idx = idx[2:]

Vsoma_idx = [Vsoma[i] for i in idx]
Vdend_idx = [Vdend[i] for i in idx]

Vsoma_fig1 = plot3_dt(Vsoma_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='somatic voltage', 
                yrange=[-86, 40], yabline = [-86, -60], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=5, dt=dt, ds=ds_plot, offset=False)        

Vdend_fig1 = plot3_dt(Vdend_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='dendritic voltage', 
                yrange=[-86, -10], yabline = [-86, -20], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=5, dt=dt, ds=ds_plot, offset=False)  

Vsoma_fig1.show(config={"toImageButtonOptions": {"format": "svg"}})
Vdend_fig1.show(config={"toImageButtonOptions": {"format": "svg"}})

if save:
    Vsoma_fig1.write_image(f"{sim_image_path}/Vsoma1.svg", format='svg', scale=3)
    Vdend_fig1.write_image(f"{sim_image_path}/Vdend1.svg", format='svg', scale=3)

# %%
idx

# %%
Vsoma_idx = [Vsoma[i] for i in idx]
Vdend_idx = [Vdend[i] for i in idx]

Vsoma_fig2 = plot3_dt(Vsoma_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='somatic voltage', 
                yrange=[-86, 160], yabline = [-86, -60], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=10, dt=dt, ds=ds_plot, offset=True, offset_ms=100, offset_y=20, width=1000, height=400) 

Vdend_fig2 = plot3_dt(Vdend_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='dendritic voltage', 
                yrange=[-86, 120], yabline = [-86, -20], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=10, dt=dt, ds=ds_plot, offset=True, offset_ms=100, offset_y=20, width=1000, height=400)     
 

Vsoma_fig2.show(config={"toImageButtonOptions": {"format": "svg"}})
Vdend_fig2.show(config={"toImageButtonOptions": {"format": "svg"}})

if save:
    Vsoma_fig2.write_image(f"{sim_image_path}/Vsoma2.svg", format='svg', scale=3)
    Vdend_fig2.write_image(f"{sim_image_path}/Vdend2.svg", format='svg', scale=3)

# %%
Vsoma_idx = [Vsoma[1] for i in idx]
Vdend_idx = [Vdend[1] for i in idx]

Vsoma_fig3 = plot3_dt(Vsoma_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='somatic voltage', 
                yrange=[-86, 160], yabline = [-86, -60], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=5, dt=dt, ds=ds_plot, offset=True, offset_ms=100, offset_y=20, width=1000, height=400) 

Vdend_fig3 = plot3_dt(Vdend_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='somatic voltage', 
                yrange=[-86, 120], yabline = [-86, -20], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=5, dt=dt, ds=ds_plot, offset=True, offset_ms=100, offset_y=20, width=1000, height=400)     
 

Vsoma_fig3.show(config={"toImageButtonOptions": {"format": "svg"}})
Vdend_fig3.show(config={"toImageButtonOptions": {"format": "svg"}})

if save:
    Vsoma_fig3.write_image(f"{sim_image_path}/Vsoma3.svg", format='svg', scale=3)
    Vdend_fig3.write_image(f"{sim_image_path}/Vdend3.svg", format='svg', scale=3)

# %%
Vsoma_idx = [Vsoma[i] for i in idx]
Vdend_idx = [Vdend[i] for i in idx]

Vsoma_fig4 = plot3_dt(Vsoma_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='somatic voltage', 
                yrange=[-86, -40], yabline = [-86, -60], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=10, dt=dt, ds=ds_plot, offset=True, offset_ms=100, offset_y=0, width=1000, height=400) 

Vdend_fig4 = plot3_dt(Vdend_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='dendritic voltage', 
                yrange=[-86, -10], yabline = [-86, -20], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=10, dt=dt, ds=ds_plot, offset=True, offset_ms=100, offset_y=0, width=1000, height=400)     
 

Vsoma_fig4.show(config={"toImageButtonOptions": {"format": "svg"}})
Vdend_fig4.show(config={"toImageButtonOptions": {"format": "svg"}})

if save:
    Vsoma_fig4.write_image(f"{sim_image_path}/Vsoma4.svg", format='svg', scale=3)
    Vdend_fig4.write_image(f"{sim_image_path}/Vdend4.svg", format='svg', scale=3)

# %%
Vsoma_idx = [Vsoma[1] for i in idx]
Vdend_idx = [Vdend[1] for i in idx]

Vsoma_fig5 = plot3_dt(Vsoma_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='somatic voltage', 
                yrange=[-86, -40], yabline = [-86, -60], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=10, dt=dt, ds=ds_plot, offset=True, offset_ms=100, offset_y=0, width=1000, height=400) 

Vdend_fig5 = plot3_dt(Vdend_idx, yaxis='V (mV)', stim_time = 130, sim_time=sim_time, title='dendritic voltage', 
                yrange=[-86, -10], yabline = [-86, -20], black_trace=None, gray_trace=None, black_shift=200, baseline=50, 
                x_err_bar=50, y_err_bar=10, dt=dt, ds=ds_plot, offset=True, offset_ms=100, offset_y=0, width=1000, height=400)     
 

Vsoma_fig5.show(config={"toImageButtonOptions": {"format": "svg"}})
Vdend_fig5.show(config={"toImageButtonOptions": {"format": "svg"}})

if save:
    Vsoma_fig5.write_image(f"{sim_image_path}/Vsoma5.svg", format='svg', scale=3)
    Vdend_fig5.write_image(f"{sim_image_path}/Vdend5.svg", format='svg', scale=3)

# %%
record_dendrite = next(iter(sim_data.values()))['metadata']['record_dendrite']
record_location = next(iter(sim_data.values()))['metadata']['record_location']

# get indices for the recording location
record_coords = get_coord_index_interp(cell_coordinates=cell_coordinates, target_dendrite=record_dendrite, target_location=record_location)
idx = get_coord_index(cell_coordinates=cell_coordinates, target_dendrite=record_dendrite, target_location=record_location)

compare_synapse_coords("Glutamatergic", record_dendrite, record_location, record_coords)

compare_synapse_coords("Glutamatergic", record_dendrite, record_location, cell_coordinates[idx][0:5,])

# %%
stim_time = next(iter(sim_data.values()))['metadata']['stim_time']
rel_timing = [t - stim_time for t in timing_range[2:]]
start_time  = np.min(timing_range)
baseline = 20

# %%
P2_soma = rel_peak_fun(V=Vsoma, timing_range=timing_range, dt=dt, start_time=start_time, baseline=baseline, omit_trace=0, sub_trace=1)[0]
P2_dend = rel_peak_fun(V=Vdend, timing_range=timing_range, dt=dt, start_time=start_time, baseline=baseline, omit_trace=0, sub_trace=1)[0]

P3_soma = peak_fun(V=Vsoma, timing_range=timing_range, dt=dt, start_time=start_time, baseline=baseline)[0]
P3_dend = peak_fun(V=Vdend, timing_range=timing_range, dt=dt, start_time=start_time, baseline=baseline)[0]

P2_P1_soma = np.round([P / P2_soma[0] for P in P2_soma[2:]], 5)
P2_P1_dend = np.round([P / P2_dend[0] for P in P2_dend[2:]], 5)

P3_P1_soma = np.round([P / P3_soma[0] for P in P3_soma[2:]], 5)
P3_P1_dend = np.round([P / P3_dend[0] for P in P3_dend[2:]], 5)

# %%
# xrange=(-40, 482)
xrange = [-102, 102]

plot4(rel_timing, P3_P1_soma, P3_P1_dend, sim_image_path=sim_image_path,
               width=3, height=2.25, marker_size=1, lwd=1, xrange=xrange, yrange=(0.85, 1.05), x_tick_step=20,
               x_title = r'$\mathrm{t}_{\mathrm{GLUT}} - \mathrm{t}_{\mathrm{GABA}}\;\mathrm{(ms)}$', y_title='P₃/P₁',
               save_name='P3_P1_plot.svg', save=True)

# %%
plot4(rel_timing, P2_P1_soma, P2_P1_dend, sim_image_path=sim_image_path,
               width=6, height=2.25, marker_size=1, lwd=1, xrange=xrange, yrange=(0, 1.25), x_tick_step=20, 
               x_title = r'$\mathrm{t}_{\mathrm{GLUT}} - \mathrm{t}_{\mathrm{GABA}}\;\mathrm{(ms)}$', y_title='P₂/P₁',
               save_name='P2_P1_plot.svg', save=True)

# %%
next(iter(sim_data.values()))['metadata']['num_gabas']

# %%
next(iter(sim_data.values()))['metadata']['scale_factors']
